# %% [markdown]
# <a href="https://colab.research.google.com/github/vprobon/iLIR-ML-data/blob/main/fetch_AF2disorder_mobidb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !cp LIRcentral_22Apr2024-UniqueIDs-Canonical.txt  uniprot_ids.txt
# !cat uniprot_ids.txt

# %%
import requests
import json
import csv

# Function to read UniProt IDs from a file
def read_uniprot_ids(file_path):
    with open(file_path, 'r') as file:
        uniprot_ids = file.read().splitlines()
    return uniprot_ids

# Function to query MobiDB for AlphaFold-disorder results
def query_mobidb(uniprot_id):
    url = f"https://mobidb.bio.unipd.it/api/download?acc={uniprot_id}&format=json"
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        return None

# Function to extract prediction-disorder-alphafold values from JSON
def extract_alphafold_disorder(json_data):
    if 'prediction-disorder-alphafold' in json_data:
        return json_data['prediction-disorder-alphafold']
    else:
        return None

# Function to save all results to a single CSV file
def save_all_results(file_path, results):
    with open(file_path, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['UniProt ID', 'AlphaFold Disorder Predictions'])
        for uniprot_id, disorder_values in results.items():
            writer.writerow([uniprot_id, disorder_values])

def main(uniprot_ids_file, output_file):
    uniprot_ids = read_uniprot_ids(uniprot_ids_file)
    results = {}
    for uniprot_id in uniprot_ids:
        if '-' in uniprot_id:
          continue
        print(f"Querying MobiDB for UniProt ID: {uniprot_id}")
        json_data = query_mobidb(uniprot_id)
        if json_data:
            disorder_values = extract_alphafold_disorder(json_data)
            if disorder_values:
                results[uniprot_id] = disorder_values
                #print(f"Results found for UniProt ID: {uniprot_id}")
            else:
                print(f"No AlphaFold disorder values for UniProt ID: {uniprot_id}")
        else:
            print(f"Failed to retrieve results for UniProt ID: {uniprot_id}")

    save_all_results(output_file, results)
    print(f"All results saved to {output_file}")

# Example usage
uniprot_ids_file = 'uniprot_ids.txt'  # Replace with your file path containing UniProt IDs
output_file = 'alphafold_disorder_predictions.csv'  # Output file to save results
main(uniprot_ids_file, output_file)
# Out:
# Querying MobiDB for UniProt ID: A0A3Q9JIX6
# No AlphaFold disorder values for UniProt ID: A0A3Q9JIX6
# Querying MobiDB for UniProt ID: A1Z995
# Querying MobiDB for UniProt ID: A5HBY5
# No AlphaFold disorder values for UniProt ID: A5HBY5
# Querying MobiDB for UniProt ID: B4F9B1
# Querying MobiDB for UniProt ID: B9EIS5
# No AlphaFold disorder values for UniProt ID: B9EIS5
# Querying MobiDB for UniProt ID: C4R8D7
# Querying MobiDB for UniProt ID: D0NBE6
# Querying MobiDB for UniProt ID: G5EC37
# Querying MobiDB for UniProt ID: H6WNF3
# No AlphaFold disorder values for UniProt ID: H6WNF3
# Querying MobiDB for UniProt ID: M1BJF6
# Querying MobiDB for UniProt ID: O13709
# Querying MobiDB for UniProt ID: O14641
# Querying MobiDB for UniProt ID: O15040
# Querying MobiDB for UniProt ID: O15111
# Querying MobiDB for UniProt ID: O15392
# Querying MobiDB for UniProt ID: O15553
# Querying MobiDB for UniProt ID: O60238
# Querying MobiDB for UniProt ID: O75143
# Querying MobiDB for UniProt ID: O75164
# Querying MobiDB for UniProt ID: O75376
# Querying MobiDB for UniProt ID: O75385
# Querying MobiDB for UniProt ID: O82245
# Querying MobiDB for UniProt ID: O82775
# Querying MobiDB for UniProt ID: O95197
# Querying MobiDB for UniProt ID: O95210
# Querying MobiDB for UniProt ID: O95782
# Querying MobiDB for UniProt ID: P01137
# Querying MobiDB for UniProt ID: P05106
# Querying MobiDB for UniProt ID: P06821
# No AlphaFold disorder values for UniProt ID: P06821
# Querying MobiDB for UniProt ID: P0C0U1
# No AlphaFold disorder values for UniProt ID: P0C0U1
# Querying MobiDB for UniProt ID: P0CK58
# No AlphaFold disorder values for UniProt ID: P0CK58
# Querying MobiDB for UniProt ID: P10909
# Querying MobiDB for UniProt ID: P14199
# Querying MobiDB for UniProt ID: P22681
# Querying MobiDB for UniProt ID: P27797
# Querying MobiDB for UniProt ID: P29353
# Querying MobiDB for UniProt ID: P30086
# Querying MobiDB for UniProt ID: P34216
# Querying MobiDB for UniProt ID: P35193
# Querying MobiDB for UniProt ID: P35222
# Querying MobiDB for UniProt ID: P38273
# Querying MobiDB for UniProt ID: P40337
# Querying MobiDB for UniProt ID: P40344
# Querying MobiDB for UniProt ID: P40458
# Querying MobiDB for UniProt ID: P46983
# Querying MobiDB for UniProt ID: P49023
# Querying MobiDB for UniProt ID: P53867
# Querying MobiDB for UniProt ID: P54252
# Querying MobiDB for UniProt ID: P55072
# Querying MobiDB for UniProt ID: P55285
# Querying MobiDB for UniProt ID: P59017
# Querying MobiDB for UniProt ID: P63244
# Querying MobiDB for UniProt ID: P70365
# Querying MobiDB for UniProt ID: P97784
# Querying MobiDB for UniProt ID: Q00610
# Querying MobiDB for UniProt ID: Q01484
# No AlphaFold disorder values for UniProt ID: Q01484
# Querying MobiDB for UniProt ID: Q05513
# Querying MobiDB for UniProt ID: Q06159
# Querying MobiDB for UniProt ID: Q07820
# Querying MobiDB for UniProt ID: Q08412
# Querying MobiDB for UniProt ID: Q09969
# Querying MobiDB for UniProt ID: Q0PF16
# Querying MobiDB for UniProt ID: Q0ZLH2
# Querying MobiDB for UniProt ID: Q10931
# Querying MobiDB for UniProt ID: Q12292
# Querying MobiDB for UniProt ID: Q12983
# Querying MobiDB for UniProt ID: Q13501
# Querying MobiDB for UniProt ID: Q14318
# Querying MobiDB for UniProt ID: Q14457
# Querying MobiDB for UniProt ID: Q14596
# Querying MobiDB for UniProt ID: Q17740
# Querying MobiDB for UniProt ID: Q22342
# Querying MobiDB for UniProt ID: Q22436
# Querying MobiDB for UniProt ID: Q23023
# Querying MobiDB for UniProt ID: Q2TAZ0
# Querying MobiDB for UniProt ID: Q3MII6
# Querying MobiDB for UniProt ID: Q3TL44
# Querying MobiDB for UniProt ID: Q4QXM1
# No AlphaFold disorder values for UniProt ID: Q4QXM1
# Querying MobiDB for UniProt ID: Q562E7
# Querying MobiDB for UniProt ID: Q5ZUV9
# No AlphaFold disorder values for UniProt ID: Q5ZUV9
# Querying MobiDB for UniProt ID: Q61026
# Querying MobiDB for UniProt ID: Q62165
# Querying MobiDB for UniProt ID: Q6DD88
# Querying MobiDB for UniProt ID: Q6P9H5
# Querying MobiDB for UniProt ID: Q6ZNE5
# Querying MobiDB for UniProt ID: Q72499
# No AlphaFold disorder values for UniProt ID: Q72499
# Querying MobiDB for UniProt ID: Q7Z434
# Querying MobiDB for UniProt ID: Q7Z6L1
# Querying MobiDB for UniProt ID: Q86M30
# No AlphaFold disorder values for UniProt ID: Q86M30
# Querying MobiDB for UniProt ID: Q86V97
# Querying MobiDB for UniProt ID: Q86VP1
# Querying MobiDB for UniProt ID: Q86WV6
# Querying MobiDB for UniProt ID: Q8BJ56
# Querying MobiDB for UniProt ID: Q8IVP5
# Querying MobiDB for UniProt ID: Q8IXH6
# Querying MobiDB for UniProt ID: Q8IYT8
# Querying MobiDB for UniProt ID: Q8IZQ1
# No AlphaFold disorder values for UniProt ID: Q8IZQ1
# Querying MobiDB for UniProt ID: Q8MQJ7
# Querying MobiDB for UniProt ID: Q8N9B5
# Querying MobiDB for UniProt ID: Q8NEB9
# Querying MobiDB for UniProt ID: Q8TD08
# Querying MobiDB for UniProt ID: Q8TD19
# Querying MobiDB for UniProt ID: Q8TDY2
# Querying MobiDB for UniProt ID: Q8VDC1
# Querying MobiDB for UniProt ID: Q8VY98
# Querying MobiDB for UniProt ID: Q8WVZ9
# Querying MobiDB for UniProt ID: Q924S7
# Querying MobiDB for UniProt ID: Q92609
# Querying MobiDB for UniProt ID: Q92830
# Querying MobiDB for UniProt ID: Q94C95
# Querying MobiDB for UniProt ID: Q95XR4
# Querying MobiDB for UniProt ID: Q969V5
# Querying MobiDB for UniProt ID: Q96A56
# Querying MobiDB for UniProt ID: Q96BY7
# Querying MobiDB for UniProt ID: Q96CV9
# Querying MobiDB for UniProt ID: Q99442
# Querying MobiDB for UniProt ID: Q99623
# Querying MobiDB for UniProt ID: Q9BQS8
# Querying MobiDB for UniProt ID: Q9BWQ8
# Querying MobiDB for UniProt ID: Q9FG23
# Querying MobiDB for UniProt ID: Q9GYV5
# Querying MobiDB for UniProt ID: Q9H0E2
# Querying MobiDB for UniProt ID: Q9H6L5
# Querying MobiDB for UniProt ID: Q9H8Y8
# Querying MobiDB for UniProt ID: Q9P1Z2
# Querying MobiDB for UniProt ID: Q9SB64
# Querying MobiDB for UniProt ID: Q9U389
# Querying MobiDB for UniProt ID: Q9UHK0
# Querying MobiDB for UniProt ID: Q9ULG6
# Querying MobiDB for UniProt ID: Q9UQF2
# Querying MobiDB for UniProt ID: Q9Y4G2
# Querying MobiDB for UniProt ID: Q9Y4K3
# Querying MobiDB for UniProt ID: Q9Y4P1
# Querying MobiDB for UniProt ID: Q9Y6I9
# Querying MobiDB for UniProt ID: Q9Y6K9
# Querying MobiDB for UniProt ID: S7URH8
# No AlphaFold disorder values for UniProt ID: S7URH8
# All results saved to alphafold_disorder_predictions.csv

# %%
# !wc -l alphafold_disorder_predictions.csv
# !tail
# Out:
# 123 alphafold_disorder_predictions.csv
